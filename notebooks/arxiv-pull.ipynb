# %%
#!pip install arxiv
import arxiv
import time
import json
import re

# %%
def pull_abstracts(category, num_batches, results_per_batch):
    abstracts = {}
    print("pulling %d abstracts from %s" % (num_batches*results_per_batch, category))
    for batch_num in range(num_batches):
        batch  = arxiv.query(search_query='cat:' + category, start = batch_num*results_per_batch, max_results=results_per_batch)
        print("\t%d: retrieved %d articles from %s" % (batch_num, len(batch), category))
        for article in batch:
            abstracts[article['id']] = article['summary']
        time.sleep(3)
    
    filename = re.sub('\.','-',category)
    with open('%s.json' % filename, 'w') as outfile:
        json.dump(abstracts, outfile)
    print("\twrote abstracts to %s.json\n" % filename)

# %%
batches=30
batchsize=1000

pull_abstracts('stat.ML', batches, batchsize)
pull_abstracts('math.AG', batches, batchsize)
pull_abstracts('hep-th', batches, batchsize)
pull_abstracts('astro-ph', batches, batchsize)
pull_abstracts('cs.CV', batches, batchsize)
# Out:
# pulling 30000 abstracts from hep-th
# 	0: retrieved 1000 articles from hep-th
# 	1: retrieved 1000 articles from hep-th
# 	2: retrieved 1000 articles from hep-th
# 	3: retrieved 1000 articles from hep-th
# 	4: retrieved 1000 articles from hep-th
# 	5: retrieved 1000 articles from hep-th
# 	6: retrieved 1000 articles from hep-th
# 	7: retrieved 1000 articles from hep-th
# 	8: retrieved 1000 articles from hep-th
# 	9: retrieved 0 articles from hep-th
# 	10: retrieved 1000 articles from hep-th
# 	11: retrieved 1000 articles from hep-th
# 	12: retrieved 1000 articles from hep-th
# 	13: retrieved 1000 articles from hep-th
# 	14: retrieved 0 articles from hep-th
# 	15: retrieved 1000 articles from hep-th
# 	16: retrieved 1000 articles from hep-th
# 	17: retrieved 1000 articles from hep-th
# 	18: retrieved 1000 articles from hep-th
# 	19: retrieved 1000 articles from hep-th
# 	20: retrieved 1000 articles from hep-th
# 	21: retrieved 1000 articles from hep-th
# 	22: retrieved 1000 articles from hep-th
# 	23: retrieved 1000 articles from hep-th
# 	24: retrieved 0 articles from hep-th
# 	25: retrieved 1000 articles from hep-th
# 	26: retrieved 1000 articles from hep-th
# 	27: retrieved 1000 articles from hep-th
# 	28: retrieved 1000 articles from hep-th
# 	29: retrieved 1000 articles from hep-th
# 	wrote abstracts to hep-th.json
#
# pulling 30000 abstracts from astro-ph
# 	0: retrieved 1000 articles from astro-ph
# 	1: retrieved 1000 articles from astro-ph
# 	2: retrieved 1000 articles from astro-ph
# 	3: retrieved 1000 articles from astro-ph
# 	4: retrieved 1000 articles from astro-ph
# 	5: retrieved 1000 articles from astro-ph
# 	6: retrieved 1000 articles from astro-ph
# 	7: retrieved 1000 articles from astro-ph
# 	8: retrieved 1000 articles from astro-ph
# 	9: retrieved 1000 articles from astro-ph
# 	10: retrieved 0 articles from astro-ph
# 	11: retrieved 1000 articles from astro-ph
# 	12: retrieved 1000 articles from astro-ph
# 	13: retrieved 1000 articles from astro-ph
# 	14: retrieved 1000 articles from astro-ph
# 	15: retrieved 1000 articles from astro-ph
# 	16: retrieved 1000 articles from astro-ph
# 	17: retrieved 1000 articles from astro-ph
# 	18: retrieved 1000 articles from astro-ph
# 	19: retrieved 0 articles from astro-ph
# 	20: retrieved 1000 articles from astro-ph
# 	21: retrieved 1000 articles from astro-ph
# 	22: retrieved 1000 articles from astro-ph
# 	23: retrieved 1000 articles from astro-ph
# 	24: retrieved 1000 articles from astro-ph
# 	25: retrieved 1000 articles from astro-ph
# 	26: retrieved 1000 articles from astro-ph
# 	27: retrieved 0 articles from astro-ph
# 	28: retrieved 1000 articles from astro-ph
# 	29: retrieved 1000 articles from astro-ph
# 	wrote abstracts to astro-ph.json
#
# pulling 30000 abstracts from cs.CV
# 	0: retrieved 1000 articles from cs.CV
# 	1: retrieved 1000 articles from cs.CV
# 	2: retrieved 1000 articles from cs.CV
# 	3: retrieved 1000 articles from cs.CV
# 	4: retrieved 1000 articles from cs.CV
# 	5: retrieved 1000 articles from cs.CV
# 	6: retrieved 1000 articles from cs.CV
# 	7: retrieved 1000 articles from cs.CV
# 	8: retrieved 1000 articles from cs.CV
# 	9: retrieved 1000 articles from cs.CV
# 	10: retrieved 1000 articles from cs.CV
# 	11: retrieved 1000 articles from cs.CV
# 	12: retrieved 1000 articles from cs.CV
# 	13: retrieved 1000 articles from cs.CV
# 	14: retrieved 1000 articles from cs.CV
# 	15: retrieved 1000 articles from cs.CV
# 	16: retrieved 1000 articles from cs.CV
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-62-1143383d32db> in <module>()
#       6 pull_abstracts('hep-th', batches, batchsize)
#       7 pull_abstracts('astro-ph', batches, batchsize)
# ----> 8 pull_abstracts('cs.CV', batches, batchsize)
#       9
#
# <ipython-input-59-3e0ad30c2e79> in pull_abstracts(category, num_batches, results_per_batch)
#       3     print("pulling %d abstracts from %s" % (num_batches*results_per_batch, category))
#       4     for batch_num in range(num_batches):
# ----> 5         batch  = arxiv.query(search_query='cat:' + category, start = batch_num*results_per_batch, max_results=results_per_batch)
#       6         print("\t%d: retrieved %d articles from %s" % (batch_num, len(batch), category))
#       7         for article in batch:
#
# /anaconda3/lib/python3.6/site-packages/arxiv/arxiv.py in query(search_query, id_list, prune, start, max_results, sort_by, sort_order)
#      33     if results.get('status') != 200:
#      34         # TODO: better error reporting
# ---> 35         raise Exception("HTTP Error " + str(results.get('status', 'no status')) + " in query")
#      36     else:
#      37         results = results['entries']
#
# Exception: HTTP Error no status in query
